# %%
#* ----------------------------------------------------------------------------------
#* BONUS POINT!                                                                     -
#* 1. Report on all OUTPUT CSV files from prior SQL runs                            -
#* 2. Using sqlalchemy, create an SQLITE of Managers                                -
#* 3. Link PANDAS-PYTHON to the SQL database, that includes all 6 relevant tables.  -
#* 4. Create an SQLITE Table out of SQL Tables of the DB:ALEMIDEPT                                       -
#* 5. Ensure Password used to access DB:ALEMIDEPT is not passed to github           -
#* 6. Create MPLOT Charts on some of the outputs, to provide a visual report        -
#*                                                          See Report #7           -
#* -                                                        Piruz Alemi, Jan 6 2020 -
#* ----------------------------------------------------------------------------------

# %%
# SQLAlchemy
from sqlalchemy import create_engine

# %%
# . Parses a Paasword
# . Perhaps! it should be placed in a config file that is placed in .ignore
import urllib.parse
urllib.parse.quote_plus("Roshan$$0*7")
# Out:
# 'Roshan%24%240%2A7'

# %%
# import output CSV files of SQL runs into Pandas_Python program
# Note to the reader: These CSV files are output files of SQL runs under PgAdmin
import pandas as pd
import os
pd.read_csv("../sql_Challenge/data-1578190645086.csv")
# Report #1: Employees Report by Dept Name.
#            . This and other subsequents reports were originally created by Alemi
#            in SQL under PgAdmin
# Out:
#         emp_no    last_name first_name           dept_name
# 0        10005     Maliniak    Kyoichi     Human Resources
# 1        10010     Piveteau  Duangkaew          Production
# 2        10010     Piveteau  Duangkaew  Quality Management
# 3        10011        Sluis       Mary    Customer Service
# 4        10013       Terkki  Eberhardt     Human Resources
# ...        ...          ...        ...                 ...
# 331598  499948    Paludetto   Cordelia          Production
# 331599  499972       Leuchs     Katsuo         Development
# 331600  499985  Lukaszewicz       Gila            Research
# 331601  499987       Dusink      Rimli               Sales
# 331602  499998      Breugel   Patricia             Finance
#
# [331603 rows x 4 columns]

# %%
pd.read_csv("../sql_Challenge/data-1578190579520.csv")
# Report #1b: List of employees and their salaries
# Out:
#         emp_no    last_name first_name gender  emp_no-2  salary
# 0        10001      Facello     Georgi      M     10001   60117
# 1        10005     Maliniak    Kyoichi      M     10005   78228
# 2        10010     Piveteau  Duangkaew      F     10010   72488
# 3        10011        Sluis       Mary      F     10011   42365
# 4        10013       Terkki  Eberhardt      M     10013   40000
# ...        ...          ...        ...    ...       ...     ...
# 300019  499967       Bodoff   Bangqing      M    499967   87170
# 300020  499972       Leuchs     Katsuo      F    499972   41002
# 300021  499985  Lukaszewicz       Gila      M    499985   40000
# 300022  499987       Dusink      Rimli      F    499987   52282
# 300023  499998      Breugel   Patricia      M    499998   40000
#
# [300024 rows x 6 columns]

# %%
pd.read_csv("../sql_Challenge/data-1578190623299.csv")
# Report #2 List of emmplyees who started in 1986
# Out:
#         from_date  emp_no  last_name first_name gender  salary
# 0      1986-06-26   10001    Facello     Georgi      M   60117
# 1      1986-12-01   10004    Koblick  Chirstian      M   40054
# 2      1986-02-26   10066   Schusler       Kwee      M   69736
# 3      1986-10-30   10081      Rosen   Zhongwei      M   55786
# 4      1986-03-14   10090    Hofting     Kendra      M   44978
# ...           ...     ...        ...        ...    ...     ...
# 19873  1986-09-09  499870      Peroz     Kayoko      M   40000
# 19874  1986-12-24  499872  Krychniak     Kannan      M   40000
# 19875  1986-04-17  499920    Murtagh     Christ      M   73573
# 19876  1986-07-03  499922    Doering  Mitsuyuki      F   50525
# 19877  1986-04-25  499940      Auria      Yolla      M   43417
#
# [19878 rows x 6 columns]

# %%
# Report #3: List of Managers by Dept with Start and End Dates.
# ------------------------------------------------------------------ 
pd.read_csv("../sql_Challenge/data-1578334458468.csv")
# Out:
#        last_name   first_name dept_no           dept_name  empl_no  \
# 0     Markovitch    Margareta  d001             Marketing   110022
# 1       Minakawa     Vishwani  d001             Marketing   110039
# 2          Alpin         Ebru  d002               Finance   110085
# 3     Legleitner        Isamu  d002               Finance   110114
# 4   Ossenbruggen      Shirish  d003       Human Resources   110183
# 5        Sigstam      Karsten  d003       Human Resources   110228
# 6        Wegerle    Krassimir  d004            Production   110303
# 7          Cools       Rosine  d004            Production   110344
# 8         Kieras         Shem  d004            Production   110386
# 9       Ghazalie        Oscar  d004            Production   110420
# 10      Hagimont     DeForest  d005           Development   110511
# 11      DasSarma         Leon  d005           Development   110567
# 12       Onuegbe    Peternela  d006    Quality Management   110725
# 13       Hofmeyr       Rutger  d006    Quality Management   110765
# 14       Quadeer       Sanjoy  d006    Quality Management   110800
# 15         Pesch         Dung  d006    Quality Management   110854
# 16     Kaelbling  Przemyslawa  d007                 Sales   111035
# 17         Zhang        Hauke  d007                 Sales   111133
# 18       Staelin         Arie  d008              Research   111400
# 19        Kambil       Hilary  d008              Research   111534
# 20   Butterworth        Tonny  d009      Customer Service   111692
# 21    Giarratana        Marjo  d009      Customer Service   111784
# 22      Spinelli      Xiaobin  d009      Customer Service   111877
# 23       Weedman      Yuchang  d009      Customer Service   111939
#
#      from_date     to_date
# 0   1985-01-01  1991-10-01
# 1   1991-10-01  9999-01-01
# 2   1985-01-01  1989-12-17
# 3   1989-12-17  9999-01-01
# 4   1985-01-01  1992-03-21
# 5   1992-03-21  9999-01-01
# 6   1985-01-01  1988-09-09
# 7   1988-09-09  1992-08-02
# 8   1992-08-02  1996-08-30
# 9   1996-08-30  9999-01-01
# 10  1985-01-01  1992-04-25
# 11  1992-04-25  9999-01-01
# 12  1985-01-01  1989-05-06
# 13  1989-05-06  1991-09-12
# 14  1991-09-12  1994-06-28
# 15  1994-06-28  9999-01-01
# 16  1985-01-01  1991-03-07
# 17  1991-03-07  9999-01-01
# 18  1985-01-01  1991-04-08
# 19  1991-04-08  9999-01-01
# 20  1985-01-01  1988-10-17
# 21  1988-10-17  1992-09-08
# 22  1992-09-08  1996-01-03
# 23  1996-01-03  9999-01-01

# %%
# Report #4 List all Employees  whose first name = "Hercules and last_Name starts with B"
# --------------------------------------------------------------------------------------
pd.read_csv("../sql_Challenge/data-1578334524360.csv")
# Out:
#    first_name      last_name xstring
# 0    Hercules     Benzmuller       B
# 1    Hercules        Brendel       B
# 2    Hercules     Baranowski       B
# 3    Hercules       Barreiro       B
# 4    Hercules           Baer       B
# 5    Hercules  Bernardinello       B
# 6    Hercules        Basagni       B
# 7    Hercules          Biran       B
# 8    Hercules        Bisiani       B
# 9    Hercules      Bernatsky       B
# 10   Hercules           Bail       B
# 11   Hercules          Birge       B
# 12   Hercules          Biron       B
# 13   Hercules         Bodoff       B
# 14   Hercules           Bain       B
# 15   Hercules        Buchter       B
# 16   Hercules           Baak       B
# 17   Hercules           Bahr       B
# 18   Hercules        Berstel       B
# 19   Hercules       Benantar       B

# %%
# Report #5 List all Employees by  Dept                                -
# ----------------------------------------------------------------------
pd.read_csv("../sql_Challenge/data-1578334497969.csv")
# Out:
#         emp_no    last_name first_name           dept_name
# 0        10005     Maliniak    Kyoichi     Human Resources
# 1        10010     Piveteau  Duangkaew          Production
# 2        10010     Piveteau  Duangkaew  Quality Management
# 3        10011        Sluis       Mary    Customer Service
# 4        10013       Terkki  Eberhardt     Human Resources
# ...        ...          ...        ...                 ...
# 331598  499948    Paludetto   Cordelia          Production
# 331599  499972       Leuchs     Katsuo         Development
# 331600  499985  Lukaszewicz       Gila            Research
# 331601  499987       Dusink      Rimli               Sales
# 331602  499998      Breugel   Patricia             Finance
#
# [331603 rows x 4 columns]

# %%
# Report #6 List all Employees in the Sales Dept
pd.read_csv("../sql_Challenge/data-1578190677227.csv")
# Out:
#        emp_no    last_name first_name dept_name
# 0       10002       Simmel    Bezalel     Sales
# 1       10016  Cappelletti   Kazuhito     Sales
# 2       10034         Swan      Bader     Sales
# 3       10041       Lenart        Uri     Sales
# 4       10050       Dredge    Yinghua     Sales
# ...       ...          ...        ...       ...
# 52240  499960     Veldwijk     Gaetan     Sales
# 52241  499966     Crabtree    Mihalis     Sales
# 52242  499967       Bodoff   Bangqing     Sales
# 52243  499976       Felder   Guozhong     Sales
# 52244  499980        Usery       Gino     Sales
#
# [52245 rows x 4 columns]

# %%
# Report #6b List all Employees in the Sales + Development Dept
pd.read_csv("../sql_Challenge/data-1578336092338.csv")
# Out:
#         emp_no      last_name first_name    dept_name
# 0        10001        Facello     Georgi  Development
# 1        10002         Simmel    Bezalel        Sales
# 2        10006        Preusig     Anneke  Development
# 3        10008       Kalloufi     Saniya  Development
# 4        10012      Bridgland   Patricio  Development
# ...        ...            ...        ...          ...
# 137947  499972         Leuchs     Katsuo  Development
# 137948  499973        Taubman      Lobel  Development
# 137949  499976         Felder   Guozhong        Sales
# 137950  499979  Waleschkowski  Prasadram  Development
# 137951  499980          Usery       Gino        Sales
#
# [137952 rows x 4 columns]

# %%
# .  Report #7: Which Last name occurs most
pd.read_csv("../sql_Challenge/data-1578190445297.csv")
# Out:
#       last_name  count
# 0          Baba    226
# 1         Coorg    223
# 2        Gelosh    223
# 3        Farris    222
# 4       Sudbeck    222
# ...         ...    ...
# 1633  Georgatos    148
# 1634       Zykh    148
# 1635      Merro    147
# 1636   Sadowsky    145
# 1637   Foolsday      1
#
# [1638 rows x 2 columns]

# %%
# Path to sqlite
database_path = "http://localhost:5432/ALEMIDEPT"

# %% [markdown]
# * -------------------------------------------------------------------
# * sqlite://<nohostname>/<path>
#
# * where <path> is relative:
# * engine = create_engine('sqlite:///Manager.db')
# * See: https://docs.sqlalchemy.org/en/13/core/engines.html#postgresql
#
# * Unix/Mac - 4 initial slashes in total
# * engine = create_engine('sqlite:////absolute/path/to/foo.db')
# * -------------------------------------------------------------------

# %%
# Import and establish Base for which classes will be constructed 
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
# Import modules to declare columns and column data types
from sqlalchemy import Column, Integer, String, Float

# %%
#------------------------------------------------
# Create Manager class(es)
#------------------------------------------------

class Manager(Base):
    __tablename__ = 'Managers'
    dept_no = Column(String(6))
    empl_no = Column(Integer, primary_key=True)
    from_date = Column(String(12))
    to_date = Column(String(12))

# %%
# .  does not connect!!!!!!!!!!!!!!!!!!!!
engine = create_engine('postgresql://postgres:Roshan2017@localhost:5432/ALEMIDEPT',pool_size=20,max_overflow=-1)
connection = engine.connect()
# https://martin-thoma.com/configuration-files-in-python/

# %%
#!/usr/bin/env python
#import databaseconfig as cfg
#connect(cfg.mysql['host'], cfg.mysql['user'], cfg.mysql['password'])

# %%
us
# Out:
# 'aaa'

# %%
#engine = create_engine(f'postgresql://{username}:{password}@localhost:{port}/{database}')
#conn = engine.connect()

# %%
#engine = create_engine(f'postgresql://{piruzalemi}:{Roshan2017}@localhost:{5432}/{ALEMIDEPT}')
#conn = engine.connect()

# %%
#-------------------------------------------------
# Create Database Connection - Does Connect
# ------------------------------------------------
# Establish Connection
engine = create_engine("sqlite:///manager.sqlite")
conn = engine.connect()

# %%
# ----------------------------------------------------------------------------------
# Create specific instances of Managers
# . Make sure you increment the empl_no as it cannot be added as a duplicate key!!!!!!!!!!!!!!!!!!!!!!!!!!!
# ----------------------------------------------------------------------------------
Managment = Manager(dept_no='d00005', empl_no=15, from_date=19970204,to_date=20200105)
#Managment = Manager(dept_no='d00009', empl_no=16, from_date=19980204,to_date=20200105)
#Managment = Manager(dept_no='d00009', empl_no=12, from_date=19980204,to_date=20200105)
#Managment = Manager(dept_no='d00008', empl_no=13, from_date=20200204,to_date=20200105)
# Managment = Manager(dept_no='d00007', empl_no=14, from_date=19560204,to_date=20200105)

# %%
# Create Managers and possibly other tables within the database
Base.metadata.create_all(conn)

# %%
# To push the objects (Management) made and query the server we use a Session object
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
# Add "Management" to the current session
session.add(Managment)
# Commit the object to the database
session.commit()

# %%
# Query the database and collect all of the Managers in the Managers table
management_list = session.query(Manager)
for bro in management_list:
    print(bro.dept_no)
    print(bro.empl_no)
    print(bro.from_date)
# Out:
# d00001
# 1
# 19960204
# d00001
# 2
# 19960204
# d00001
# 3
# 19960204
# d00004
# 4
# 19960204
# d00009
# 12
# 19980204
# d00008
# 13
# 20200204
# d00007
# 14
# 19560204
# d00009
# 16
# 19980204

# %%
#--Import Matplot lib
import numpy as np

import matplotlib
from matplotlib import style
style.use('seaborn')
import matplotlib.pyplot as plt

# %%
# .  Report #7 again!: Which Last name occurs most
pd.read_csv("../sql_Challenge/data-1578190445297.csv")
# Out:
#       last_name  count
# 0          Baba    226
# 1         Coorg    223
# 2        Gelosh    223
# 3        Farris    222
# 4       Sudbeck    222
# ...         ...    ...
# 1633  Georgatos    148
# 1634       Zykh    148
# 1635      Merro    147
# 1636   Sadowsky    145
# 1637   Foolsday      1
#
# [1638 rows x 2 columns]

# %%
#input_df = pd.read_csv("../sql_Challenge/data-1578190445297.csv", delimiter=',', names = ['last_name', 'counter'])
input_df = pd.read_csv("../sql_Challenge/data-1578190445297.csv",nrows=10)
input_df.head(10)
# Out:
#   last_name  count
# 0      Baba    226
# 1     Coorg    223
# 2    Gelosh    223
# 3    Farris    222
# 4   Sudbeck    222
# 5    Adachi    221
# 6    Osgood    220
# 7   Mandell    218
# 8    Masada    218
# 9    Neiman    218

# %%
# Set x axis and tick locations
x_axis = np.arange(len(input_df))
tick_locations = [value for value in x_axis]
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, input_df["count"], color='b', alpha=0.5, align="center")
plt.xticks(tick_locations, input_df["last_name"], rotation="vertical")
# Set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(215, max(input_df["count"])+10)
# Set a Title and labels
plt.title("Top 10 Repeated Frequencies of Last-Names in Employees file")
plt.xlabel("Last Names")
plt.ylabel("Frequency of occurance")
plt.tight_layout()
plt.savefig("../sql_challenge/lastName_Freq.png")
plt.show()

# %%
#plt.tight_layout()
#plt.savefig("../sql_challenge/lastName_Freq.png")
#plt.show()
